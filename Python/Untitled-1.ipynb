# %%
import YouTubeAudioDownloader2

# %%
YouTubeAudioDownloader2.download_audio('https://www.youtube.com/watch?v=foLFvVY5y84&ab_channel=Metroplane-Topic', dest_dir=r'C:\Users\Usuario\Music\Musica JB\archivos de musica')
# Out:
# ---------------------------------------------------------------------------
# RegexMatchError                           Traceback (most recent call last)
# File c:\Python\Python396\lib\site-packages\pytube\__main__.py:181, in YouTube.fmt_streams(self)
#     180 try:
# --> 181     extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     182 except exceptions.ExtractError:
#     183     # To force an update to the js file, we clear the cache and retry
#
# File c:\Python\Python396\lib\site-packages\pytube\extract.py:409, in apply_signature(stream_manifest, vid_info, js)
#     401 """Apply the decrypted signature to the stream manifest.
#     402
#     403 :param dict stream_manifest:
#    (...)
#     407
#     408 """
# --> 409 cipher = Cipher(js=js)
#     411 for i, stream in enumerate(stream_manifest):
#
# File c:\Python\Python396\lib\site-packages\pytube\cipher.py:43, in Cipher.__init__(self, js)
#      38 self.js_func_patterns = [
# ...

# %%
YouTubeAudioDownloader2.search_playlists(playlist_directory=r'C:\Users\Usuario\Music\MusicBee\Playlists', audio_file_directory=r"C:\Users\Usuario\Music\Musica JB\archivos de musica\Sade - Smooth Operator.mp3")
# Out:
# Playlists in the provided directory:
# 1. 70s_80s.m3u
# 2. 90s Techno_Dance.m3u
# 3. Acid.m3u
# 4. Africana.m3u
# 5. Ambient.m3u
# 6. Arriba.m3u
# 7. Aster Amanece Shh.m3u
# 8. Añadidas Recientemente.m3u
# 9. Bombas Rumanas.m3u
# 10. Bossa Nova_Samba.m3u
# 11. Cachengue (_).m3u
# 12. Castellano.m3u
# 13. Chamán.m3u
# 14. Charly García.m3u
# 15. Clásica.m3u
# 16. Conga.m3u
# 17. Cumbia.m3u
# 18. Deep_House Luminoso.m3u
# 19. DJ's Gone Disco.m3u
# 20. Duroscuro.m3u
# 21. Electric Jazz.m3u
# 22. Electro Cool _ Micro.m3u
# 23. Electro para el Recuerdo.m3u
# 24. Electrónica (todo).m3u
# 25. Flashero.m3u
# 26. Folclore.m3u
# 27. Franchutes.m3u
# 28. Hard Rock.m3u
# 29. House.m3u
# 30. Inglés (viejas).m3u
# 31. Jazz_Blues.m3u
# 32. Juan.m3u
# 33. Luis Alberto Spinetta.m3u
# 34. Matzi (campari, menetas y musiquita).m3u
# 35. Naviwep.m3u
# 36. Pacha 2013.m3u
# 37. Pala Energizante.m3u
# 38. Piano.m3u
# 39. Pity Álvarez.m3u
# 40. Pop Wa.m3u
# 41. Prepara el ataque aereo.m3u
# 42. Progre.m3u
# ...

# %%
import os
audio_file_directory=r"C:\Users\Usuario\Music\Musica JB\archivos de musica\Sade - Smooth Operator.mp3"
playlist_directory = r"C:\Users\Usuario\Music\MusicBee\Playlists"
playlists = []
for file in os.listdir(playlist_directory):
    if file.endswith(".m3u"):
        playlists.append(file)

print("Playlists in the provided directory:")
for playlist in playlists:
    for i, playlist in enumerate(playlists, start=1):
        print(f"{i}. {playlist}")
    
playlist_numbers = 51
# Out:
# Playlists in the provided directory:
# 1. 70s_80s.m3u
# 2. 90s Techno_Dance.m3u
# 3. Acid.m3u
# 4. Africana.m3u
# 5. Ambient.m3u
# 6. Arriba.m3u
# 7. Aster Amanece Shh.m3u
# 8. Añadidas Recientemente.m3u
# 9. Bombas Rumanas.m3u
# 10. Bossa Nova_Samba.m3u
# 11. Cachengue (_).m3u
# 12. Castellano.m3u
# 13. Chamán.m3u
# 14. Charly García.m3u
# 15. Clásica.m3u
# 16. Conga.m3u
# 17. Cumbia.m3u
# 18. Deep_House Luminoso.m3u
# 19. DJ's Gone Disco.m3u
# 20. Duroscuro.m3u
# 21. Electric Jazz.m3u
# 22. Electro Cool _ Micro.m3u
# 23. Electro para el Recuerdo.m3u
# 24. Electrónica (todo).m3u
# 25. Flashero.m3u
# 26. Folclore.m3u
# 27. Franchutes.m3u
# 28. Hard Rock.m3u
# 29. House.m3u
# 30. Inglés (viejas).m3u
# 31. Jazz_Blues.m3u
# 32. Juan.m3u
# 33. Luis Alberto Spinetta.m3u
# 34. Matzi (campari, menetas y musiquita).m3u
# 35. Naviwep.m3u
# 36. Pacha 2013.m3u
# 37. Pala Energizante.m3u
# 38. Piano.m3u
# 39. Pity Álvarez.m3u
# 40. Pop Wa.m3u
# 41. Prepara el ataque aereo.m3u
# 42. Progre.m3u
# ...

# %%
playlist_numbers="n"
if playlist_numbers == 'no':
    print("Audio file not moved to any playlist.")
else:
    try:
        selected_playlists = [int(num.strip()) for num in str(playlist_numbers).split(",")]
        for playlist_number in selected_playlists:
            if 1 <= playlist_number <= len(playlists):
                selected_playlist = playlists[playlist_number - 1]
                add_to_playlist(playlist_directory, selected_playlist, audio_file_directory)
            else:
                print("Invalid playlist number!")
    except ValueError:
        print("Invalid playlist number!")
# Out:
# Invalid playlist number!

# %%
playlist_numbers='51,52'
[int(num.strip()) for num in str(playlist_numbers).split(",")]
# Out:
# [51, 52]

# %%
import re
bool(re.search(r'\d+', playlist_numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 import re
# ----> 2 bool(re.search(r'\d+', playlist_numbers))
#
# File c:\Python\Python396\lib\re.py:201, in search(pattern, string, flags)
#     198 def search(pattern, string, flags=0):
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object

# %%
playlist_numbers.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 playlist_numbers.lower()
#
# AttributeError: 'int' object has no attribute 'lower'

# %%
YouTubeAudioDownloader2.download_audio(url='https://www.youtube.com/watch?v=7hdBo5kxfGo&ab_channel=LennyKravitz-Topic')
# Out:
# ---------------------------------------------------------------------------
# RegexMatchError                           Traceback (most recent call last)
# File c:\Python\Python396\lib\site-packages\pytube\__main__.py:181, in YouTube.fmt_streams(self)
#     180 try:
# --> 181     extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     182 except exceptions.ExtractError:
#     183     # To force an update to the js file, we clear the cache and retry
#
# File c:\Python\Python396\lib\site-packages\pytube\extract.py:409, in apply_signature(stream_manifest, vid_info, js)
#     401 """Apply the decrypted signature to the stream manifest.
#     402
#     403 :param dict stream_manifest:
#    (...)
#     407
#     408 """
# --> 409 cipher = Cipher(js=js)
#     411 for i, stream in enumerate(stream_manifest):
#
# File c:\Python\Python396\lib\site-packages\pytube\cipher.py:43, in Cipher.__init__(self, js)
#      38 self.js_func_patterns = [
# ...
